# %%
import os
# Fixes the silent kernel crash
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

import torch
from ultralytics import YOLO

print("GPU Available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("Using GPU:", torch.cuda.get_device_name(0))

# %%
# %%writefile data.yaml
# path: C:/Users/lenovo/Desktop/IITB/SoC/Assignment
# train: train/train/images
# val: valid/valid/images
#
# # Replace these with the actual defect names from your dataset
# names:
#   0: crazing
#   1: inclusion
#   2: patches
#   3: pitted_surface
#   4: rolled-in_scale
#   5: scratches

# %%
import os
# Prevent the background library conflict crash
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

import torch
from ultralytics import YOLO

# Double-check that your GPU is ready
print("GPU Available:", torch.cuda.is_available())

# Load the model
model = YOLO('yolov8n.pt')

# Start training with memory & browser safety nets applied
results = model.train(
    data='data.yaml',
    epochs=50,
    imgsz=640,
    batch=8,       
    device=0,      
    workers=0,     
    plots=True,
    verbose=False,
    # THE ULTIMATE FIX: Save in a completely unprotected, non-syncing directory
    project='C:/Users/lenovo/YOLO_Defect_Results', 
    name='Training_Run_1'               
)
