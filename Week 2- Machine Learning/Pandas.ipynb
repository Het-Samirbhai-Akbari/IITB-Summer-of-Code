# %%
#WHAT IS PANDAS?
#PANDAS is a python library which is used to maintain and handle large datasets.
print("INTRODUCTION TO PANDAS")

# %%
# !conda install pandas #install PANDAS library

# %% [markdown]
# # KEY DATA STRUCTURES IN PANDAS
#   * Series
#   * DataFrame

# %%
import pandas as pd #import pandas library

# %%
s=pd.Series([1,2,3,4,5], index=['a','b','c','d','e'])

# %%
s

# %%
df=pd.DataFrame({ "Names":["A","B","C"], "Marks":["50","60","70"]}, index=['1','2','3'])

# %%
df

# %%
import os
print(os.getcwd())#see the current working directory

# %%
df=pd.read_csv("hasbro.csv")#read the data of hasbro.csv

# %%
df

# %%
df.head()  #see FIRST 5 ROWS

# %%
df.tail() #see last 5 rows

# %%
df.describe() #gives basic details like mean,median,etc.

# %%
df.info() #gives no. of rows colums and other info.

# %% [markdown]
# # Data Selection

# %%
type(df["Email Confidence"]) #Gives which data structure was used to make this data

# %%
df["Email Confidence"] #Gives the whole data of the field

# %%
df[["Email Confidence","Home Phone"]] #Gives data of both

# %%
df.iloc[2] #Gives entire row data

# %%
df.dropna() #removes rows which have even a single empty cell

# %%
df.fillna(0) #fills empty space with 0
# if we write df.fillna(0, inplace=True), the changes will be made in the original file too.

# %%
df.rename(columns={"Title":"Designation"}) #Change column name

# %%
# to change data type of a column- df["name"]=df["name"].astype(datatype)

# %%
len(df)#length of sheet

# %%
df["ABC"]=[0 for i in range(len(df))]

# %%
df
