# %% [markdown]
# <!-- #Naive Bayes is a classic and highly effective method for spam detection because it is fast, simple, and handles text data very well.
#
# It works on the principle of probability—specifically, calculating the likelihood that an email is "spam" or "not spam" based on the individual words it contains.
#
# How the Process Works
# 1. Training (Learning from History)
# Before it can detect spam, the model needs to be trained on a large dataset of emails already labeled as "Spam" or "Ham" (legitimate).
#
# The model counts the occurrences of every word in both categories.
#
# It calculates the probability of each word appearing in a spam email versus a ham email.
#
# Example: It learns that the word "lottery" has a 0.8 probability of appearing in spam, while "meeting" has a 0.01 probability.
#
# 2. The Naive Assumption
# The "Naive" part of the name comes from a simplifying assumption: it assumes that the presence of one word is independent of the presence of any other word. * Even though in reality, "free" and "money" often appear together, the model treats them as separate, independent clues.
#
# This makes the math incredibly fast and allows the model to handle thousands of unique words without crashing.
#
# 3. Prediction (The Math)
# When a new email arrives, the model breaks it down into a list of words. For each word, it asks: "Given that this word is in the email, what is the probability that the email is spam?"
#
# The model combines these individual probabilities to calculate a final score for the email. If the combined probability exceeds a certain threshold (e.g., 50%), the email is flagged as spam.
#
# Key Advantages for Email Filtering
# Adaptability: It learns very quickly. If you mark a new type of spam email as "spam," the model immediately updates its probability counts for those words.
#
# Efficiency: Because it only needs to count words and multiply probabilities, it requires very little computing power, making it perfect for processing millions of emails in real-time.
#
# Low Data Requirement: It can achieve high accuracy with a relatively small training set compared to more complex models like deep neural networks.
#
# The Limitation
# Because it assumes words are independent, it can sometimes be "fooled" by spammers who use word-stuffing or complex sentence structures. However, for a quick, automated first line of defense, it remains the industry gold standard for many lightweight filtering systems.
#
# Are you planning to implement a spam filter using this logic, or are you looking for a comparison between Naive Bayes and other classification models? -->

# %% [markdown]
# #Naive Bayes is a classic and highly effective method for spam detection because it is fast, simple, and handles text data very well.
#
# It works on the principle of probability—specifically, calculating the likelihood that an email is "spam" or "not spam" based on the individual words it contains.
#
# How the Process Works
# 1. Training (Learning from History)
# Before it can detect spam, the model needs to be trained on a large dataset of emails already labeled as "Spam" or "Ham" (legitimate).
#
# The model counts the occurrences of every word in both categories.
#
# It calculates the probability of each word appearing in a spam email versus a ham email.
#
# Example: It learns that the word "lottery" has a 0.8 probability of appearing in spam, while "meeting" has a 0.01 probability.
#
# 2. The Naive Assumption
# The "Naive" part of the name comes from a simplifying assumption: it assumes that the presence of one word is independent of the presence of any other word. * Even though in reality, "free" and "money" often appear together, the model treats them as separate, independent clues.
#
# This makes the math incredibly fast and allows the model to handle thousands of unique words without crashing.
#
# 3. Prediction (The Math)
# When a new email arrives, the model breaks it down into a list of words. For each word, it asks: "Given that this word is in the email, what is the probability that the email is spam?"
#
# The model combines these individual probabilities to calculate a final score for the email. If the combined probability exceeds a certain threshold (e.g., 50%), the email is flagged as spam.
#
# Key Advantages for Email Filtering
# Adaptability: It learns very quickly. If you mark a new type of spam email as "spam," the model immediately updates its probability counts for those words.
#
# Efficiency: Because it only needs to count words and multiply probabilities, it requires very little computing power, making it perfect for processing millions of emails in real-time.
#
# Low Data Requirement: It can achieve high accuracy with a relatively small training set compared to more complex models like deep neural networks.
#
# The Limitation
# Because it assumes words are independent, it can sometimes be "fooled" by spammers who use word-stuffing or complex sentence structures. However, for a quick, automated first line of defense, it remains the industry gold standard for many lightweight filtering systems.

# %%
import pandas as pd

# %%
df = pd.read_csv("spam.csv")
df.head()

# %%
df.groupby('Category').describe()

# %%
df['spam']=df['Category'].apply(lambda x: 1 if x=='spam' else 0)
df.head()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.Message,df.spam)

# %%
from sklearn.feature_extraction.text import CountVectorizer
v = CountVectorizer()
X_train_count = v.fit_transform(X_train.values)
X_train_count.toarray()[:2]

# %%
from sklearn.naive_bayes import MultinomialNB
model = MultinomialNB()
model.fit(X_train_count,y_train)

# %%
emails = [
    'Hey mohan, can we get together to watch footbal game tomorrow?',
    'Upto 20% discount on parking, exclusive offer just for you. Dont miss this reward!'
]
emails_count = v.transform(emails)
model.predict(emails_count)

# %%
X_test_count = v.transform(X_test)
model.score(X_test_count, y_test)

# %% [markdown]
# **Sklearn Pipeline**

# %%
from sklearn.pipeline import Pipeline
clf = Pipeline([
    ('vectorizer', CountVectorizer()),
    ('nb', MultinomialNB())
])

# %%
clf.fit(X_train, y_train)

# %%
clf.score(X_test,y_test)

# %%
clf.predict(emails)
