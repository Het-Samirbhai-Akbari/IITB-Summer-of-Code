# %%
import pandas as pd
df=pd.read_csv("carprices.csv")
df.head()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(df["Mileage"],df["Sell Price($)"])

# %%
plt.scatter(df["Age(yrs)"],df["Sell Price($)"])

# %%
X = df[['Mileage','Age(yrs)']]
y = df['Sell Price($)']

# %%
X

# %%
y

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2) # Test dataset size=20% and training dataset size=80%
# Also if we want no randomness, we can use random_state=number

# %%
len(X_train)

# %%
len(X_test)

# %%
X_train #The library RANDOMLY seledts 16 datapoints for training

# %%
from sklearn.linear_model import LinearRegression
clf =  LinearRegression()

# %%
clf.fit(X_train,y_train)

# %%
clf.predict(X_test) # testing

# %%
y_test

# %%
clf.score(X_test,y_test)

# %% [markdown]
# # NOTE
# # THE ACCURACY OF THE MODEL DEPENDS ON THE DATASET CHOSEN FOR TRAINING AND TEST
