# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("canada per capita income.csv")
df

# %%
# %matplotlib inline
plt.xlabel('year')
plt.ylabel('per capita income (US$)')
plt.scatter(df.year, df['per capita income (US$)'], color='red', marker='+')
plt.plot(df.year,reg.predict(df[['year']]),color='blue')

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['year']],df['per capita income (US$)'])

# %%
reg.predict([[2020]])

# %%
reg.coef_ #gives slope

# %%
reg.intercept_ #gives intercept

# %% [markdown]
# # To predict this data for other excel file

# %%
#d=pd.read_csv("filename.csv")
#reg.predict(d) will predict the same for the sheet
# you can also make a new column for this:
# p=reg.predict(d) 
#d['pricees'] = p
# d.to_csv("datafilename.csv") will export this data to the file
